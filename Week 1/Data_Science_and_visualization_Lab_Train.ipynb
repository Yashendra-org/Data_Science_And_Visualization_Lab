# %%
import pandas as pd
df = pd.read_csv('train.csv')
print("--- Dataset Head ---")
print(df.head())
print("--- Summary Info ---")
print(df.info())
print("--- Summary Statistics ---")
print(df.describe())
print("--- Missing Values Count ---")
print(df.isnull().sum())
