# %%
import pandas as pd
df = pd.read_csv('Iris.csv')
print("--- Dataset Head ---")
print(df.head())
print("--- Dataset Info ---")
print(df.info())
print("--- Summary Statistics ---")
print(df.describe())
print("--- Missing Values Count ---")
print(df.isnull().sum())
